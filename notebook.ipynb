# %%
import requests, pandas as pd
from pathlib import Path
from sqlalchemy import create_engine

url = "https://github.com/lerocha/chinook-database/raw/master/ChinookDatabase/DataSources/Chinook_Sqlite.sqlite"
p = Path("db/Chinook.sqlite")
p.write_bytes(requests.get(url, timeout=60).content)

engine = create_engine(f"sqlite:///{p.as_posix()}")

# Entrada de fechas
year1 = pd.to_datetime("2010" + "-01-01")
year2 = pd.to_datetime("2012"+ "-12-31")

# Asegurar orden
date1, date2 = sorted([year1, year2])
date1 = date1.strftime('%Y-%m-%d 00:00:00')
date2 = date2.strftime('%Y-%m-%d 23:59:59')

# Consulta
query = f'''
SELECT 
  t.Name AS TrackName, 
  ar.Name AS ArtistName, 
  a.Title AS AlbumTitle, 
  COALESCE(t.Composer, 'unknown') AS composer, 
  g.Name AS Genre,
  COUNT(il.TrackId) AS quantity, 
  COALESCE(SUM(il.UnitPrice), 0) AS total_income,
  COUNT(pt.TrackId) AS popularity

FROM Track t
LEFT JOIN Genre g   ON t.GenreId = g.GenreId 
LEFT JOIN Album a   ON t.AlbumId = a.AlbumId
LEFT JOIN Artist ar ON a.ArtistId = ar.ArtistId
LEFT JOIN InvoiceLine il ON t.TrackId = il.TrackId
LEFT JOIN Invoice i ON i.InvoiceId = il.InvoiceId
LEFT JOIN PlaylistTrack pt ON pt.TrackId = t.TrackId

WHERE i.InvoiceDate BETWEEN '{date1}' AND '{date2}'

GROUP BY t.Name, ar.Name, a.Title, t.Composer, g.Name
ORDER BY total_income DESC

'''

display(pd.read_sql(query, engine))
# Out:
#                                               TrackName  \
# 0     Scheherazade, Op. 35: I. The Sea and Sindbad's...
# 1       Suite No. 3 in D, BWV 1068: III. Gavotte I & II
# 2     Symphonie Fantastique, Op. 14: V. Songe d'une ...
# 3                                        Gay Witch Hunt
# 4                          How to Stop an Exploding Man
# ...                                                 ...
# 1291                                         [Untitled]
# 1292                                           Às Vezes
# 1293                                      Água de Beber
# 1294                                             É Fogo
# 1295                                             Óculos
#
#                                              ArtistName  \
# 0             Chicago Symphony Orchestra & Fritz Reiner
# 1     Academy of St. Martin in the Fields, Sir Nevil...
# 2        Michael Tilson Thomas & San Francisco Symphony
# 3                                            The Office
# 4                                                Heroes
# ...                                                 ...
# 1291                                  Smashing Pumpkins
# 1292                                            O Terço
# 1293                                       Marcos Valle
# 1294                                    Mônica Marianno
# 1295                            Os Paralamas Do Sucesso
#
#                               AlbumTitle  \
# 0                           Scheherazade
# 1     Bach: Orchestral Suites Nos. 1 - 4
# 2         Berlioz: Symphonie Fantastique
# 3                   The Office, Season 3
# 4                       Heroes, Season 1
# ...                                  ...
# 1291        Rotten Apples: Greatest Hits
# 1292                        Compositores
# 1293              Chill: Brazil (Disc 1)
# 1294                          Demorou...
# 1295     Arquivo Os Paralamas Do Sucesso
#
#                                      composer               Genre  quantity  \
# 0                     Nikolai Rimsky-Korsakov           Classical        10
# 1                       Johann Sebastian Bach           Classical        10
# 2                              Hector Berlioz           Classical        10
# 3                                     unknown            TV Shows         4
# 4                                     unknown               Drama         4
# ...                                       ...                 ...       ...
# 1291                             Billy Corgan  Alternative & Punk         2
# 1292                                  unknown                Rock         2
# 1293  Antonio Carlos Jobim/Vinicius de Moraes               Latin         2
# 1294                          Mônica Marianno               World         2
# 1295                                  unknown               Latin         2
#
#       total_income  popularity
# 0             9.90          10
# 1             9.90          10
# 2             9.90          10
# 3             7.96           4
# 4             7.96           4
# ...            ...         ...
# 1291          1.98           2
# 1292          1.98           2
# 1293          1.98           2
# 1294          1.98           2
# 1295          1.98           2
#
# [1296 rows x 8 columns]
